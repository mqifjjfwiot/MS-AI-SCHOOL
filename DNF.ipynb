# %% [markdown]
# <a href="https://colab.research.google.com/github/mqifjjfwiot/MS-AI-SCHOOL/blob/main/DNF.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests

# %%
# https://developers.neople.co.kr/contents/apiDocs/df

# %%
url = "https://api.neople.co.kr/df/servers?apikey=OdDHDUpXhIi8keFplIqDXJuwPjGu4Dc8"
api_query = "apikey=OdDHDUpXhIi8keFplIqDXJuwPjGu4Dc8"

# %% [markdown]
# ![캡처.JPG](data:image/jpeg;base64,...)

# %%
# requests.get() # GET 요청
# requests.post() # POST 요청
# requests.put() # PUT 요청
# requests.delete() # DELETE 요청

# %%
headers = {'Content-Type': 'application/json; charset=utf-8'}
response = requests.get(url, headers=headers)

# %%
itemId
